# %%
Git

Version 1- initial draft
version 2- minor corrections
version 3-


rollback

# %%
#Repository- Proect folder
#commit- saved check points
#branch- seperate version of the work
#merge- combine two versions
#push and pull
