# %%
#variables
student_name= "Riya"
student_age = 20

print (student_name)
print (student_age)
# Out:
# Riya
# 20

# %%
student_name = "riya"
#camel casing bugFix
#camelCasingBugfix
#name, age, course

# %%
student_name= "Riya"
student_age = 20
attendance= 85.5
is_present= True


print(type(student_name))
print(type(student_age))
print(type(attendance))
print(type(is_present))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
marks= "85"
print(marks + 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1863/4121376848.py in <cell line: 0>()
#       1 marks= "85"
# ----> 2 print(marks + 5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
marks = "85"
marks = int(marks)
print(marks + 5)
# Out:
# 90

# %%
mark1=8
mark2=72


marks= [78,85,91,26]

# %%
student =["aman",19, "AIML", 88]
student ={
    "name": "aman",
    "age": 19,
    "course": "AIML",
    "marks": 88
}
print(student["name"])
print(student["marks"])
# Out:
# aman
# 88

# %%
#My profile-name, course, favourtite, confidence score

#print your name and favourite topic

#1
print(student[name])
#
print(student["name"])

# %%
marks= 72

if marks>=26:
  print("Pass")
else:
  print("fail")
# Out:
# Pass

# %%
marks= 72

if marks>=80:
  print("strong in studies")
elif marks>=40:
  print("average in studies")
else
  print("weak in studies")

# %%
#if a number i postive, negative or zero

number= -5

# %%
marks= [78,85,91,26]

for mark in marks:
  print(mark)
# Out:
# 78
# 85
# 91
# 26

# %%
marks= [78,35,91,22,72]

for mark in marks:
  if mark>=40:
    print("pass")
  else:
    print("fail")
# Out:
# pass
# fail
# pass
# fail
# pass

# %%
marks= [78,35,91,22,72]
#marks more than 75 strong, 40 print average else needs improvement

for mark in marks:
  if mark>=75:
    print("strong")
  elif mark>=40:
    print("average")
  else:
    print("needs improvement")

# %%
#combining all concepts


students = [
    {"name": "Aarav", "study_hours": 6, "attendance": 85, "marks": 78},
    {"name": "Riya", "study_hours": 3, "attendance": 70, "marks": 55},
    {"name": "Kabir", "study_hours": 8, "attendance": 90, "marks": 88},
    {"name": "Meera", "study_hours": 2, "attendance": 60, "marks": 35}
]



#marks are more than 75 print perferamce strong


#attendance is less than 75, print low attendance

#if student has studied for less than 4 hours, Warning needs more study time
