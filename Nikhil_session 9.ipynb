# %%
#I grew up in France. I moved to India. I studied engineering. I speak fluent ___.

# %%
#LSTM LONG SHORT TERM MEMORY

#LSTM= RNN + cell state + gates


#LSTM has two memory paths
#cell state- long term memory
#hidden state is current working memory

# %%
#Cell state in LSTM is the long term memory
#hidden state os the current memory


#Ganesh watched the movie. The food was not good.

# %%
#The movie was not good.


#Input gate decides, candidate memory stores
#candidate memory

# %%
#The movie was not good.

import tensorflow as tf
from tensorflow.keras import layers


#hyperparameters
vocab_size= 1000
embedding_dim = 16
sequence_length= 8


#LSTM architecture
lstm_model= tf.keras.Sequential([
    #first embedding layer will be defined
    layers.Embedding(
        input_dim= vocab_size,
        output_dim= embedding_dim,
        input_length= sequence_length
    ),

    layers.LSTM(32),

    layers.Dense(1, activation='sigmoid')
])

lstm_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
#The animal did not cross the street because it was tired.


#current token:
#IT
#relevant tokens to it
#animal

# %%
#The cat drank milk because it was hungry.

#The cat drank milk because it was cold.

# %%
#Dog bites man
#man bites dog


#artificial intelligence is transforming the ___

#SOTA- state of the art models

# %%
#Factors for going on a run:-

#is it raining(-1), is it a weekend(+1), is it a holiday (=2)


#biases
#i prefer indors (negative bias)
#i am a fitness freak (positive bias )
# Out:
#   File "/tmp/ipykernel_761/4149549801.py", line 1
#     Factors for going on a run:-
#             ^
# SyntaxError: invalid syntax
